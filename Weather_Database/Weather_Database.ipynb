# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from scipy.stats import linregress

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 714

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a87cccea06092130398e827240b4207a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gat
# Processing Record 2 of Set 1 | tomatlan
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 1 | adrar
# Processing Record 7 of Set 1 | heishan
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | kuala terengganu
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | wagar
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | chuy
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | sarkand
# Processing Record 29 of Set 1 | kashi
# Processing Record 30 of Set 1 | sorland
# Processing Record 31 of Set 1 | kandi
# Processing Record 32 of Set 1 | solnechnyy
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | uruana
# Processing Record 36 of Set 1 | kudahuvadhoo
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | myrtle beach
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | flin flon
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | alyangula
# Processing Record 46 of Set 1 | margate
# Processing Record 47 of Set 1 | zakamensk
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | lazaro cardenas
# Processing Record 2 of Set 2 | sao felix do xingu
# Processing Record 3 of Set 2 | buala
# Processing Record 4 of Set 2 | tateyama
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | taybad
# Processing Record 7 of Set 2 | axim
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | saint-augustin
# Processing Record 10 of Set 2 | saint anthony
# Processing Record 11 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 2 | riohacha
# Processing Record 14 of Set 2 | ananas
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | touros
# Processing Record 18 of Set 2 | sibolga
# Processing Record 19 of Set 2 | cabedelo
# Processing Record 20 of Set 2 | pandan
# Processing Record 21 of Set 2 | assiniboia
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | khasan
# Processing Record 24 of Set 2 | zaysan
# Processing Record 25 of Set 2 | maldonado
# Processing Record 26 of Set 2 | eunice
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | pochutla
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | sfantu gheorghe
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | kruisfontein
# Processing Record 33 of Set 2 | hays
# Processing Record 34 of Set 2 | punta alta
# Processing Record 35 of Set 2 | oktyabrskoye
# Processing Record 36 of Set 2 | tuatapere
# Processing Record 37 of Set 2 | stony mountain
# Processing Record 38 of Set 2 | kongwa
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | sao joao da barra
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | katsuura
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | nikolskoye
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | cheyenne
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | padang
# Processing Record 3 of Set 3 | san antonio
# Processing Record 4 of Set 3 | asau
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | malakal
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | rudbar
# Processing Record 11 of Set 3 | ballina
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 3 | san vito
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | bluff
# Processing Record 17 of Set 3 | zhigansk
# Processing Record 18 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | tuxpan
# Processing Record 21 of Set 3 | ndele
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | russell
# Processing Record 26 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | palmer
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | camacha
# Processing Record 31 of Set 3 | neyvo-shaytanskiy
# Processing Record 32 of Set 3 | marawi
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | yerbogachen
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | karratha
# Processing Record 38 of Set 3 | lakes entrance
# Processing Record 39 of Set 3 | alta floresta
# Processing Record 40 of Set 3 | kholtoson
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | kasulu
# Processing Record 43 of Set 3 | hofn
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 3 | khani
# Processing Record 47 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 3 | itarema
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | romny
# Processing Record 1 of Set 4 | aliwal north
# Processing Record 2 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | mugur-aksy
# Processing Record 6 of Set 4 | portland
# Processing Record 7 of Set 4 | morant bay
# Processing Record 8 of Set 4 | aripuana
# Processing Record 9 of Set 4 | lorengau
# Processing Record 10 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 4 | kulhudhuffushi
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | tres picos
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | ardakan
# Processing Record 18 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 4 | vao
# Processing Record 20 of Set 4 | glencoe
# Processing Record 21 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | panjakent
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | karakol
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | arraial do cabo
# Processing Record 29 of Set 4 | constitucion
# Processing Record 30 of Set 4 | goundam
# Processing Record 31 of Set 4 | sidi bu zayd
# City not found. Skipping...
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | yilan
# Processing Record 34 of Set 4 | broome
# Processing Record 35 of Set 4 | ouallam
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | kapit
# Processing Record 38 of Set 4 | yellowknife
# Processing Record 39 of Set 4 | havoysund
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | ishigaki
# Processing Record 43 of Set 4 | kimbe
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | arman
# Processing Record 46 of Set 4 | fiche
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | mujiayingzi
# Processing Record 49 of Set 4 | ambon
# Processing Record 50 of Set 4 | avera
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | vostok
# Processing Record 3 of Set 5 | lagunas
# Processing Record 4 of Set 5 | bandipur
# Processing Record 5 of Set 5 | alice springs
# Processing Record 6 of Set 5 | brumado
# Processing Record 7 of Set 5 | brae
# Processing Record 8 of Set 5 | muros
# Processing Record 9 of Set 5 | awbari
# Processing Record 10 of Set 5 | valley city
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | kushima
# Processing Record 13 of Set 5 | araouane
# Processing Record 14 of Set 5 | bosaso
# Processing Record 15 of Set 5 | barranca
# Processing Record 16 of Set 5 | figeac
# Processing Record 17 of Set 5 | yaan
# Processing Record 18 of Set 5 | ust-barguzin
# Processing Record 19 of Set 5 | huaiyuan
# Processing Record 20 of Set 5 | harindanga
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 5 | ambovombe
# Processing Record 24 of Set 5 | tura
# Processing Record 25 of Set 5 | samarai
# Processing Record 26 of Set 5 | gushikawa
# Processing Record 27 of Set 5 | dunedin
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | meulaboh
# Processing Record 30 of Set 5 | sabang
# Processing Record 31 of Set 5 | chaves
# Processing Record 32 of Set 5 | reconquista
# Processing Record 33 of Set 5 | omsukchan
# Processing Record 34 of Set 5 | belyy yar
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | northam
# Processing Record 37 of Set 5 | hambantota
# Processing Record 38 of Set 5 | nantucket
# Processing Record 39 of Set 5 | kieta
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | hvide sande
# Processing Record 43 of Set 5 | soyo
# Processing Record 44 of Set 5 | cidreira
# Processing Record 45 of Set 5 | lunenburg
# Processing Record 46 of Set 5 | port keats
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | outjo
# Processing Record 49 of Set 5 | rabat
# Processing Record 50 of Set 5 | vardo
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | sobolevo
# Processing Record 3 of Set 6 | sibu
# Processing Record 4 of Set 6 | olafsvik
# Processing Record 5 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | juneau
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | gejiu
# Processing Record 10 of Set 6 | baoqing
# Processing Record 11 of Set 6 | mokhotlong
# Processing Record 12 of Set 6 | grand gaube
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | najran
# Processing Record 15 of Set 6 | huarmey
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | chernyshevskiy
# Processing Record 18 of Set 6 | lata
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | batsfjord
# Processing Record 22 of Set 6 | dwarka
# Processing Record 23 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 6 | xiaoshi
# Processing Record 25 of Set 6 | linxia
# Processing Record 26 of Set 6 | ust-nera
# Processing Record 27 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 28 of Set 6 | mount gambier
# Processing Record 29 of Set 6 | kiama
# Processing Record 30 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 6 | bambanglipuro
# Processing Record 32 of Set 6 | gizo
# Processing Record 33 of Set 6 | dongsheng
# Processing Record 34 of Set 6 | pisco
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | waipawa
# Processing Record 40 of Set 6 | airai
# Processing Record 41 of Set 6 | hasaki
# Processing Record 42 of Set 6 | terrace
# Processing Record 43 of Set 6 | sechura
# Processing Record 44 of Set 6 | port hardy
# Processing Record 45 of Set 6 | coihaique
# Processing Record 46 of Set 6 | papetoai
# Processing Record 47 of Set 6 | khatanga
# Processing Record 48 of Set 6 | san policarpo
# Processing Record 49 of Set 6 | east london
# Processing Record 50 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 7 | castleisland
# Processing Record 2 of Set 7 | kulykiv
# Processing Record 3 of Set 7 | albury
# Processing Record 4 of Set 7 | saint george
# Processing Record 5 of Set 7 | ayan
# Processing Record 6 of Set 7 | isangel
# Processing Record 7 of Set 7 | jonkoping
# Processing Record 8 of Set 7 | sault sainte marie
# Processing Record 9 of Set 7 | tongliao
# Processing Record 10 of Set 7 | andros town
# Processing Record 11 of Set 7 | jalu
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | save
# Processing Record 14 of Set 7 | san carlos del zulia
# Processing Record 15 of Set 7 | makakilo city
# Processing Record 16 of Set 7 | kinel-cherkassy
# Processing Record 17 of Set 7 | pangkalanbuun
# Processing Record 18 of Set 7 | jinchang
# Processing Record 19 of Set 7 | belmonte
# Processing Record 20 of Set 7 | snyder
# Processing Record 21 of Set 7 | chase
# Processing Record 22 of Set 7 | ambulu
# Processing Record 23 of Set 7 | gazojak
# Processing Record 24 of Set 7 | panzhihua
# Processing Record 25 of Set 7 | geraldton
# Processing Record 26 of Set 7 | cherskiy
# Processing Record 27 of Set 7 | egvekinot
# Processing Record 28 of Set 7 | acarau
# Processing Record 29 of Set 7 | kourou
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | tilichiki
# Processing Record 32 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | lodwar
# Processing Record 35 of Set 7 | manjacaze
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | broken hill
# Processing Record 38 of Set 7 | jalingo
# Processing Record 39 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 7 | kaduqli
# Processing Record 41 of Set 7 | yadgir
# Processing Record 42 of Set 7 | san patricio
# Processing Record 43 of Set 7 | cornwall
# Processing Record 44 of Set 7 | midland
# Processing Record 45 of Set 7 | fortuna foothills
# Processing Record 46 of Set 7 | zahir pir
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | tocopilla
# Processing Record 49 of Set 7 | wolfville
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 2 of Set 8 | ankang
# Processing Record 3 of Set 8 | kingaroy
# Processing Record 4 of Set 8 | malabo
# Processing Record 5 of Set 8 | dhanwar
# Processing Record 6 of Set 8 | tygda
# Processing Record 7 of Set 8 | taltal
# Processing Record 8 of Set 8 | srandakan
# Processing Record 9 of Set 8 | santa cruz
# Processing Record 10 of Set 8 | taitung
# Processing Record 11 of Set 8 | manzhouli
# Processing Record 12 of Set 8 | amahai
# Processing Record 13 of Set 8 | filingue
# Processing Record 14 of Set 8 | praia da vitoria
# Processing Record 15 of Set 8 | codrington
# Processing Record 16 of Set 8 | nishihara
# Processing Record 17 of Set 8 | songjianghe
# Processing Record 18 of Set 8 | barrow
# Processing Record 19 of Set 8 | itape
# Processing Record 20 of Set 8 | sorong
# Processing Record 21 of Set 8 | manaure
# Processing Record 22 of Set 8 | visnes
# Processing Record 23 of Set 8 | iqaluit
# Processing Record 24 of Set 8 | dingle
# Processing Record 25 of Set 8 | bhinmal
# Processing Record 26 of Set 8 | fare
# Processing Record 27 of Set 8 | beringovskiy
# Processing Record 28 of Set 8 | port blair
# Processing Record 29 of Set 8 | plettenberg bay
# Processing Record 30 of Set 8 | njinikom
# Processing Record 31 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 8 | sarai
# Processing Record 33 of Set 8 | petropavlovka
# Processing Record 34 of Set 8 | copiapo
# Processing Record 35 of Set 8 | mithimna
# City not found. Skipping...
# Processing Record 36 of Set 8 | umm lajj
# Processing Record 37 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 8 | baykit
# Processing Record 40 of Set 8 | atambua
# Processing Record 41 of Set 8 | tessalit
# Processing Record 42 of Set 8 | muroto
# Processing Record 43 of Set 8 | harnosand
# Processing Record 44 of Set 8 | harrison
# Processing Record 45 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 46 of Set 8 | voyvozh
# Processing Record 47 of Set 8 | lodhran
# Processing Record 48 of Set 8 | corner brook
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | udachnyy
# Processing Record 1 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 9 | paka
# Processing Record 3 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 9 | la ronge
# Processing Record 5 of Set 9 | pangnirtung
# Processing Record 6 of Set 9 | acapulco
# Processing Record 7 of Set 9 | mangochi
# Processing Record 8 of Set 9 | takoradi
# Processing Record 9 of Set 9 | salina cruz
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | kokopo
# Processing Record 12 of Set 9 | manzanillo
# Processing Record 13 of Set 9 | kholmogory
# Processing Record 14 of Set 9 | pahrump
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | mackay
# Processing Record 17 of Set 9 | itoman
# Processing Record 18 of Set 9 | banda aceh
# Processing Record 19 of Set 9 | surt
# Processing Record 20 of Set 9 | bouar
# Processing Record 21 of Set 9 | marzuq
# Processing Record 22 of Set 9 | cocorit
# Processing Record 23 of Set 9 | yumen
# Processing Record 24 of Set 9 | rach gia
# Processing Record 25 of Set 9 | labuhan
# Processing Record 26 of Set 9 | palauig
# Processing Record 27 of Set 9 | ichinohe
# Processing Record 28 of Set 9 | rawatsar
# Processing Record 29 of Set 9 | alugan
# Processing Record 30 of Set 9 | soe
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | beroroha
# Processing Record 33 of Set 9 | pullman
# Processing Record 34 of Set 9 | divnoye
# Processing Record 35 of Set 9 | ugoofaaru
# Processing Record 36 of Set 9 | lebedyn
# Processing Record 37 of Set 9 | tual
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | sadiqabad
# Processing Record 40 of Set 9 | paamiut
# Processing Record 41 of Set 9 | rawson
# Processing Record 42 of Set 9 | hirara
# Processing Record 43 of Set 9 | beloha
# Processing Record 44 of Set 9 | pilar
# Processing Record 45 of Set 9 | fomboni
# Processing Record 46 of Set 9 | almaznyy
# Processing Record 47 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 48 of Set 9 | havre-saint-pierre
# Processing Record 49 of Set 9 | isla mujeres
# Processing Record 50 of Set 9 | berdigestyakh
# Processing Record 1 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 2 of Set 10 | sao filipe
# Processing Record 3 of Set 10 | terrace bay
# Processing Record 4 of Set 10 | mayo
# Processing Record 5 of Set 10 | zyryanka
# Processing Record 6 of Set 10 | khombole
# Processing Record 7 of Set 10 | maragogi
# Processing Record 8 of Set 10 | zhangjiakou
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | aketi
# Processing Record 11 of Set 10 | grindavik
# Processing Record 12 of Set 10 | cagliari
# Processing Record 13 of Set 10 | buin
# Processing Record 14 of Set 10 | jutai
# Processing Record 15 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 16 of Set 10 | fuzhou
# Processing Record 17 of Set 10 | atar
# Processing Record 18 of Set 10 | kailua
# Processing Record 19 of Set 10 | shelburne
# Processing Record 20 of Set 10 | kahului
# Processing Record 21 of Set 10 | ostrovnoy
# Processing Record 22 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 23 of Set 10 | ginir
# Processing Record 24 of Set 10 | hervey bay
# Processing Record 25 of Set 10 | vieste
# Processing Record 26 of Set 10 | jumla
# Processing Record 27 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 10 | verkhnevilyuysk
# Processing Record 29 of Set 10 | tongzi
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | zeerust
# Processing Record 32 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 10 | jagalur
# Processing Record 34 of Set 10 | lavrentiya
# Processing Record 35 of Set 10 | lexington
# Processing Record 36 of Set 10 | bilma
# Processing Record 37 of Set 10 | eureka
# Processing Record 38 of Set 10 | shache
# Processing Record 39 of Set 10 | ossora
# Processing Record 40 of Set 10 | jibuti
# Processing Record 41 of Set 10 | conceicao da barra
# Processing Record 42 of Set 10 | thinadhoo
# Processing Record 43 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 44 of Set 10 | sudak
# Processing Record 45 of Set 10 | dvinskoy
# Processing Record 46 of Set 10 | svetlogorsk
# Processing Record 47 of Set 10 | skjervoy
# Processing Record 48 of Set 10 | ust-kuyga
# Processing Record 49 of Set 10 | belgrade
# Processing Record 50 of Set 10 | maceio
# Processing Record 1 of Set 11 | lormi
# Processing Record 2 of Set 11 | los llanos de aridane
# Processing Record 3 of Set 11 | ketchikan
# Processing Record 4 of Set 11 | novoagansk
# Processing Record 5 of Set 11 | totness
# Processing Record 6 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 11 | grand-santi
# Processing Record 8 of Set 11 | trebnje
# Processing Record 9 of Set 11 | sisimiut
# Processing Record 10 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 11 | devadanapatti
# City not found. Skipping...
# Processing Record 12 of Set 11 | porto walter
# Processing Record 13 of Set 11 | sinop
# Processing Record 14 of Set 11 | san ignacio
# Processing Record 15 of Set 11 | ha tinh
# Processing Record 16 of Set 11 | worthington
# Processing Record 17 of Set 11 | san ramon de la nueva oran
# Processing Record 18 of Set 11 | shubarshi
# Processing Record 19 of Set 11 | melton
# Processing Record 20 of Set 11 | port augusta
# Processing Record 21 of Set 11 | lesnoy
# Processing Record 22 of Set 11 | kerrobert
# Processing Record 23 of Set 11 | mikhaylovka
# Processing Record 24 of Set 11 | chifeng
# Processing Record 25 of Set 11 | san javier
# Processing Record 26 of Set 11 | pangai
# Processing Record 27 of Set 11 | rio grande
# Processing Record 28 of Set 11 | ginda
# Processing Record 29 of Set 11 | xuddur
# Processing Record 30 of Set 11 | urengoy
# Processing Record 31 of Set 11 | maturin
# Processing Record 32 of Set 11 | lucapa
# Processing Record 33 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 34 of Set 11 | iwaki
# Processing Record 35 of Set 11 | nouadhibou
# Processing Record 36 of Set 11 | lenine
# Processing Record 37 of Set 11 | luorong
# Processing Record 38 of Set 11 | yeppoon
# Processing Record 39 of Set 11 | belaya gora
# Processing Record 40 of Set 11 | nemuro
# Processing Record 41 of Set 11 | salym
# Processing Record 42 of Set 11 | crawfordsville
# Processing Record 43 of Set 11 | faya
# Processing Record 44 of Set 11 | talcher
# Processing Record 45 of Set 11 | carahue
# Processing Record 46 of Set 11 | lamar
# Processing Record 47 of Set 11 | santa maria
# Processing Record 48 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 11 | vila franca do campo
# Processing Record 50 of Set 11 | guacimo
# Processing Record 1 of Set 12 | moroni
# Processing Record 2 of Set 12 | rayong
# Processing Record 3 of Set 12 | algiers
# Processing Record 4 of Set 12 | qidong
# Processing Record 5 of Set 12 | tripoli
# Processing Record 6 of Set 12 | kautokeino
# Processing Record 7 of Set 12 | okoneshnikovo
# Processing Record 8 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | bowmore
# Processing Record 10 of Set 12 | jimo
# Processing Record 11 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 12 | san quintin
# Processing Record 13 of Set 12 | vanavara
# Processing Record 14 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 12 | oktyabrskiy
# Processing Record 16 of Set 12 | vienne
# Processing Record 17 of Set 12 | lujan
# Processing Record 18 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 12 | viedma
# Processing Record 20 of Set 12 | yemelyanovo
# Processing Record 21 of Set 12 | rocha
# Processing Record 22 of Set 12 | kigoma
# Processing Record 23 of Set 12 | qiongshan
# Processing Record 24 of Set 12 | lavumisa
# Processing Record 25 of Set 12 | beaverlodge
# Processing Record 26 of Set 12 | shakawe
# Processing Record 27 of Set 12 | tarakan
# Processing Record 28 of Set 12 | beira
# Processing Record 29 of Set 12 | bintulu
# Processing Record 30 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 12 | mae sot
# Processing Record 32 of Set 12 | carutapera
# Processing Record 33 of Set 12 | eirunepe
# Processing Record 34 of Set 12 | merrill
# Processing Record 35 of Set 12 | aasiaat
# Processing Record 36 of Set 12 | kargasok
# Processing Record 37 of Set 12 | urumqi
# Processing Record 38 of Set 12 | sire
# Processing Record 39 of Set 12 | kuminskiy
# Processing Record 40 of Set 12 | veraval
# Processing Record 41 of Set 12 | kiruna
# Processing Record 42 of Set 12 | yakeshi
# Processing Record 43 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 12 | cascais
# Processing Record 45 of Set 12 | matara
# Processing Record 46 of Set 12 | san pietro in casale
# Processing Record 47 of Set 12 | lubango
# Processing Record 48 of Set 12 | tongren
# Processing Record 49 of Set 12 | martapura
# Processing Record 50 of Set 12 | anadyr
# Processing Record 1 of Set 13 | bonavista
# Processing Record 2 of Set 13 | krasnoselkup
# Processing Record 3 of Set 13 | havelock
# Processing Record 4 of Set 13 | beli potok
# Processing Record 5 of Set 13 | santa fe
# Processing Record 6 of Set 13 | trincomalee
# Processing Record 7 of Set 13 | marshall
# Processing Record 8 of Set 13 | yulin
# Processing Record 9 of Set 13 | kapoeta
# Processing Record 10 of Set 13 | puerto escondido
# Processing Record 11 of Set 13 | kamenka
# Processing Record 12 of Set 13 | tottori
# Processing Record 13 of Set 13 | berezovyy
# Processing Record 14 of Set 13 | socuellamos
# Processing Record 15 of Set 13 | kainan
# Processing Record 16 of Set 13 | puerto ayacucho
# Processing Record 17 of Set 13 | xaltianguis
# Processing Record 18 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 13 | cap malheureux
# Processing Record 20 of Set 13 | vysokogornyy
# Processing Record 21 of Set 13 | pyay
# Processing Record 22 of Set 13 | coihueco
# Processing Record 23 of Set 13 | saint-pierre
# Processing Record 24 of Set 13 | muriwai beach
# Processing Record 25 of Set 13 | trapani
# Processing Record 26 of Set 13 | prince george
# Processing Record 27 of Set 13 | bathsheba
# Processing Record 28 of Set 13 | abu samrah
# Processing Record 29 of Set 13 | sandnessjoen
# Processing Record 30 of Set 13 | half moon bay
# Processing Record 31 of Set 13 | vozhega
# Processing Record 32 of Set 13 | itapirapua
# Processing Record 33 of Set 13 | yunhe
# Processing Record 34 of Set 13 | san cristobal
# Processing Record 35 of Set 13 | carlsbad
# Processing Record 36 of Set 13 | primero de enero
# Processing Record 37 of Set 13 | bhopal
# Processing Record 38 of Set 13 | neiafu
# Processing Record 39 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 40 of Set 13 | letka
# Processing Record 41 of Set 13 | tshane
# Processing Record 42 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 13 | batemans bay
# Processing Record 44 of Set 13 | huaraz
# Processing Record 45 of Set 13 | coahuayana
# Processing Record 46 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 13 | port-gentil
# Processing Record 48 of Set 13 | catole do rocha
# Processing Record 49 of Set 13 | lixourion
# Processing Record 50 of Set 13 | kloulklubed
# Processing Record 1 of Set 14 | inirida
# Processing Record 2 of Set 14 | khorixas
# Processing Record 3 of Set 14 | vila velha
# Processing Record 4 of Set 14 | george town
# Processing Record 5 of Set 14 | tucurui
# Processing Record 6 of Set 14 | senanga
# Processing Record 7 of Set 14 | keizer
# Processing Record 8 of Set 14 | barcelos
# Processing Record 9 of Set 14 | haines junction
# Processing Record 10 of Set 14 | betong
# Processing Record 11 of Set 14 | mbaiki
# Processing Record 12 of Set 14 | naron
# Processing Record 13 of Set 14 | barranco
# Processing Record 14 of Set 14 | honiara
# Processing Record 15 of Set 14 | puquio
# Processing Record 16 of Set 14 | jamkhed
# Processing Record 17 of Set 14 | evensk
# Processing Record 18 of Set 14 | tommot
# Processing Record 19 of Set 14 | vanimo
# Processing Record 20 of Set 14 | vizinga
# Processing Record 21 of Set 14 | boyolangu
# Processing Record 22 of Set 14 | tongling
# Processing Record 23 of Set 14 | kenai
# Processing Record 24 of Set 14 | bullhead city
# Processing Record 25 of Set 14 | yen bai
# Processing Record 26 of Set 14 | tadine
# Processing Record 27 of Set 14 | tokmak
# Processing Record 28 of Set 14 | crestview
# Processing Record 29 of Set 14 | rio gallegos
# Processing Record 30 of Set 14 | sarh
# Processing Record 31 of Set 14 | sheltozero
# Processing Record 32 of Set 14 | kifri
# Processing Record 33 of Set 14 | florina
# Processing Record 34 of Set 14 | port macquarie
# Processing Record 35 of Set 14 | panjab
# Processing Record 36 of Set 14 | tigil
# Processing Record 37 of Set 14 | the pas
# Processing Record 38 of Set 14 | verkhnyaya inta
# Processing Record 39 of Set 14 | pathein
# Processing Record 40 of Set 14 | manadhoo
# Processing Record 41 of Set 14 | kaeo
# Processing Record 42 of Set 14 | lang son
# Processing Record 43 of Set 14 | hami
# Processing Record 44 of Set 14 | bulaevo
# Processing Record 45 of Set 14 | jurmala
# Processing Record 46 of Set 14 | spornoye
# Processing Record 47 of Set 14 | san rafael del sur
# Processing Record 48 of Set 14 | marsh harbour
# Processing Record 49 of Set 14 | nador
# Processing Record 50 of Set 14 | mata
# Processing Record 1 of Set 15 | mormugao
# Processing Record 2 of Set 15 | port said
# Processing Record 3 of Set 15 | kununurra
# Processing Record 4 of Set 15 | sambava
# Processing Record 5 of Set 15 | kajaani
# Processing Record 6 of Set 15 | dhidhdhoo
# Processing Record 7 of Set 15 | paytug
# City not found. Skipping...
# Processing Record 8 of Set 15 | honningsvag
# Processing Record 9 of Set 15 | yarada
# Processing Record 10 of Set 15 | san luis
# Processing Record 11 of Set 15 | fergus falls
# Processing Record 12 of Set 15 | guepsa
# Processing Record 13 of Set 15 | moron
# Processing Record 14 of Set 15 | erechim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 647

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0               Gat  31.61   34.76     62.01        72           0
# 1          Tomatlan  19.93 -105.25     71.85        93           1
# 2            Avarua -21.21 -159.78     75.20        83          50
# 3         Busselton -33.65  115.33     82.99        29           0
# 4             Adrar  20.50  -10.07     80.11        29          60
# 5           Heishan  41.69  122.11     58.42        30           0
# 6           Kavieng  -2.57  150.80     85.12        65          84
# 7          Thompson  55.74  -97.86     14.00        92          90
# 8         Esperance -33.87  121.90     62.60        72          90
# 9  Kuala Terengganu   5.33  103.14     87.80        74          40
#
#    Wind Speed Country Current Description
# 0        4.14      IL           clear sky
# 1        2.44      MX           clear sky
# 2        5.82      CK    scattered clouds
# 3        8.34      AU           clear sky
# 4       11.36      MR       broken clouds
# 5       17.09      CN           clear sky
# 6       11.54      PG       broken clouds
# 7        6.93      CA          light snow
# 8       14.99      AU     overcast clouds
# 9        6.93      MY    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0               Gat      IL  31.61   34.76     62.01        72           0
# 1          Tomatlan      MX  19.93 -105.25     71.85        93           1
# 2            Avarua      CK -21.21 -159.78     75.20        83          50
# 3         Busselton      AU -33.65  115.33     82.99        29           0
# 4             Adrar      MR  20.50  -10.07     80.11        29          60
# 5           Heishan      CN  41.69  122.11     58.42        30           0
# 6           Kavieng      PG  -2.57  150.80     85.12        65          84
# 7          Thompson      CA  55.74  -97.86     14.00        92          90
# 8         Esperance      AU -33.87  121.90     62.60        72          90
# 9  Kuala Terengganu      MY   5.33  103.14     87.80        74          40
#
#    Wind Speed Current Description
# 0        4.14           clear sky
# 1        2.44           clear sky
# 2        5.82    scattered clouds
# 3        8.34           clear sky
# 4       11.36       broken clouds
# 5       17.09           clear sky
# 6       11.54       broken clouds
# 7        6.93          light snow
# 8       14.99     overcast clouds
# 9        6.93    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
